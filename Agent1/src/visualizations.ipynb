# %%
# %matplotlib inline
# %run sim
# Out:
# [*********************100%***********************]  1 of 1 completed
# Training episode 1
# Epsilon: 0.99
# Episode 3 showed irregularity. MSE was 11866944.202839801. Showing big 10 biggest jumps in QTable below.
#                  0           1           2
# states
# 7339    506.900984  670.300001  560.578714
# 4239    518.749519  262.902325  926.229328
# 1139    556.340912  182.068498  592.947472
# 4229    689.128067  185.655747  432.027103
# 3239    386.487154  113.425241  677.016126
# 2139    340.020725  282.877273  458.653492
# 6339    324.673372  334.515154  392.152806
# 5239    413.133765  176.084334  384.270114
# 5339    295.429019  396.912445  263.054823
# 5229     94.024819  481.060419  251.124503
#
#
#
#
#
# Episode 9 showed irregularity. MSE was 32861113.34096291. Showing big 10 biggest jumps in QTable below.
#                   0            1            2
# states
# 1239    1012.395906   361.313627   847.242266
# 0139     848.887597  1499.186546  -174.473706
# ...
