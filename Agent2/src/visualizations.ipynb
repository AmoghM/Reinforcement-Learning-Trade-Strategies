# %%
# %matplotlib inline
# %run sim
# Out:
# [*********************100%***********************]  1 of 1 completed
# 500
# Training episode 1
# Epsilon: 0.99
# Episode 3 showed irregularity. MSE was 8309841.481071685. Showing big 10 biggest jumps in QTable below.
#                  0           1           2
# states
# 018     292.507897  267.102504  276.655454
# 028     -41.684790  351.237859  519.816951
# 128     411.026676  178.854661  204.088181
# 635      92.870193  206.927381  469.173710
# 634     251.251861  499.976451   -6.201926
# 534     310.999114 -110.072270  514.530412
# 524     502.619520  222.515035  -46.695191
# 224     198.921726   37.626719  441.773209
# 734     254.792375  108.305299  290.594335
# 828     254.944474  178.600619  152.535216
#
#
#
#
#
# Episode 6 showed irregularity. MSE was 9781591.37683743. Showing big 10 biggest jumps in QTable below.
#                  0           1             2
# states
# 831     578.487310  450.818398  7.039213e+01
# 223     743.544804  362.499312 -2.697845e+01
# ...
