# %%
# Resources:
# https://medium.com/python-data/setting-up-a-bollinger-band-with-python-28941e2fa300

# %%
from pandas_datareader import data as pdr
import yfinance as yf
import datetime
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# In-Sample (Training): 01/01/2007 - 12/31/2016
# Out-of-Sample (Testing): 01/01/2017 - 12/31/2019
start_date_train= datetime.datetime(2007, 1, 1)
end_date_train = datetime.datetime(2016, 12, 31)

# %%
yf.pdr_override()

# %%
sp500 = pdr.get_data_yahoo('^GSPC', 
                           start_date_train,
                             end_date_train)
                          
print(sp500)
sp500.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-01-03  1418.030029  1429.420044  1407.859985  1416.599976  1416.599976
# 2007-01-04  1416.599976  1421.839966  1408.430054  1418.339966  1418.339966
# 2007-01-05  1418.339966  1418.339966  1405.750000  1409.709961  1409.709961
# 2007-01-08  1409.260010  1414.979980  1403.969971  1412.839966  1412.839966
# 2007-01-09  1412.839966  1415.609985  1405.420044  1412.109985  1412.109985
# ...                 ...          ...          ...          ...          ...
# 2016-12-23  2260.250000  2263.790039  2258.840088  2263.790039  2263.790039
# 2016-12-27  2266.229980  2273.820068  2266.149902  2268.879883  2268.879883
# 2016-12-28  2270.229980  2271.310059  2249.110107  2249.919922  2249.919922
# 2016-12-29  2249.500000  2254.510010  2244.560059  2249.260010  2249.260010
# ...

# %%
apple = pdr.get_data_yahoo('AAPL', 
                           start_date_train,
                             end_date_train)
                          
print(apple)
apple.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2007-01-03   3.081786   3.092143   2.925000   2.992857   2.586245  1238319600
# 2007-01-04   3.001786   3.069643   2.993572   3.059286   2.643649   847260400
# 2007-01-05   3.063214   3.078571   3.014286   3.037500   2.624823   834741600
# 2007-01-08   3.070000   3.090357   3.045714   3.052500   2.637785   797106800
# 2007-01-09   3.087500   3.320714   3.041071   3.306072   2.856907  3349298400
# ...               ...        ...        ...        ...        ...         ...
# 2016-12-23  28.897499  29.129999  28.897499  29.129999  27.636169    56998000
# 2016-12-27  29.129999  29.450001  29.122499  29.315001  27.811686    73187600
# 2016-12-28  29.379999  29.504999  29.049999  29.190001  27.693100    83623600
# 2016-12-29  29.112499  29.277500  29.100000  29.182501  27.685980    60158000
# ...

# %%
apple_adjc = pd.DataFrame(apple['Adj Close'])

# %%
apple_adjc.rolling(20).mean()
# Out:
#             Adj Close
# Date
# 2007-01-03        NaN
# 2007-01-04        NaN
# 2007-01-05        NaN
# 2007-01-08        NaN
# 2007-01-09        NaN
# ...               ...
# 2016-12-23  26.896528
# 2016-12-27  26.964005
# 2016-12-28  27.026858
# 2016-12-29  27.100502
# 2016-12-30  27.175570
#
# [2518 rows x 1 columns]

# %%
ax = apple_adjc.plot(title="Apple rolling mean")

# %%
apple_adjc.plot(label="Rolling mean", ax=ax)
ax.set_xlabel("Date")
ax.set_ylabel("Price")
ax.legend(loc="upper left")
plt.show()

# %%
ax

# %%
apple_adjc.rolling(20).std()
# Out:
#             Adj Close
# Date
# 2007-01-03        NaN
# 2007-01-04        NaN
# 2007-01-05        NaN
# 2007-01-08        NaN
# 2007-01-09        NaN
# ...               ...
# 2016-12-23   0.675838
# 2016-12-27   0.697218
# 2016-12-28   0.703748
# 2016-12-29   0.691061
# 2016-12-30   0.641417
#
# [2518 rows x 1 columns]

# %%
#upper_band = rm + rstd * 2

# %%
apple_adjc.rolling(20).mean() + apple_adjc.rolling(20).std() * 2
# Out:
#             Adj Close
# Date
# 2007-01-03        NaN
# 2007-01-04        NaN
# 2007-01-05        NaN
# 2007-01-08        NaN
# 2007-01-09        NaN
# ...               ...
# 2016-12-23  28.248204
# 2016-12-27  28.358441
# 2016-12-28  28.434354
# 2016-12-29  28.482623
# 2016-12-30  28.458404
#
# [2518 rows x 1 columns]
